# %% [markdown]
# # Assignment 2
# ## Names: Anant Bamba SN : 301430478, Harmeet Singh Bhullar SN: 301541206

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import nltk
from nltk import word_tokenize
from nltk import FreqDist
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
import spacy
nlp = spacy.load("en_core_web_sm")
from spacy import displacy
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
df = pd.read_csv('./A2/Airline_review.csv', encoding = 'utf-8', usecols = ["Airline Name","Review_Title","Review","Verified"])

# %%
df.head()
# Out:
#     Airline Name                           Review_Title  Verified  \
# 0    AB Aviation                "pretty decent airline"      True
# 1    AB Aviation                   "Not a good airline"      True
# 2    AB Aviation         "flight was fortunately short"      True
# 3  Adria Airways    "I will never fly again with Adria"     False
# 4  Adria Airways  "it ruined our last days of holidays"      True
#
#                                               Review
# 0    Moroni to Moheli. Turned out to be a pretty ...
# 1   Moroni to Anjouan. It is a very small airline...
# 2    Anjouan to Dzaoudzi. A very small airline an...
# 3    Please do a favor yourself and do not fly wi...
# 4   Do not book a flight with this airline! My fr...

# %%
df= df[df["Verified"]==True]
Adria_df=df[df["Airline Name"]=="Adria Airways"]
Lufthansa_df=df[df["Airline Name"]=="Lufthansa"] 
Turkish_df=df[df["Airline Name"]=="Turkish Airlines"]

# %%
Turkish_df.drop("Verified",axis = 1).head()
# Out:
#            Airline Name                      Review_Title  \
# 21158  Turkish Airlines              "dismal to be exact"
# 21159  Turkish Airlines       "I will miss my connection"
# 21161  Turkish Airlines  "flights could have been better"
# 21162  Turkish Airlines        "My worst ever experience"
# 21163  Turkish Airlines         "Application not working"
#
#                                                   Review
# 21158   The ticketing and flight experiences, both, w...
# 21159    Last time that I will fly with Turkish Airli...
# 21161   Extra legroom not possible for over 65. We bo...
# 21162    My worst ever experience. I travelled with b...
# 21163   Flight from Beijing to Istanbul. Application ...

# %%
Lufthansa_df.drop("Verified",axis = 1).head()
# Out:
#       Airline Name                         Review_Title  \
# 14078    Lufthansa       "The customer service was bad"
# 14079    Lufthansa         "Truly excellent experience"
# 14080    Lufthansa  "there was a massive baggage delay"
# 14081    Lufthansa    "always an unpleasant experience"
# 14085    Lufthansa      "Second time I’ve had problems"
#
#                                                   Review
# 14078    London to Berlin via Munich. The day before ...
# 14079    Truly excellent experience with Lufthansa. F...
# 14080    Flight was delayed by about 60+ mins on the ...
# 14081   This is becoming a rule when I fly with Lufth...
# 14085    For reasons of bad weather we were redirecte...

# %%
Adria_df.drop("Verified",axis = 1).head()
# Out:
#      Airline Name                           Review_Title  \
# 4   Adria Airways  "it ruined our last days of holidays"
# 5   Adria Airways              "Had very bad experience"
# 8   Adria Airways                 "combined two flights"
# 9   Adria Airways                    "the crew was nice"
# 11  Adria Airways                 "bad customer service"
#
#                                                Review
# 4    Do not book a flight with this airline! My fr...
# 5     Had very bad experience with rerouted and ca...
# 8     Worst Airline ever! They combined two flight...
# 9    Ljubljana to Munich. The homebase airport of ...
# 11    Vienna to Sofia. The flight was delayed by 2...

# %%
Adria_rev = Adria_df['Review'].dropna()

# %%
Adria_rev
# Out:
# 4      Do not book a flight with this airline! My fr...
# 5       Had very bad experience with rerouted and ca...
# 8       Worst Airline ever! They combined two flight...
# 9      Ljubljana to Munich. The homebase airport of ...
# 11      Vienna to Sofia. The flight was delayed by 2...
# 12      We were traveling from Paris to Skopje on Ma...
# 13      Ljubljana to Munich. Adria's checkin system ...
# 14      A very unpleasant experience for my family. ...
# 15      Frankfurt to Ljubljana. Flight was very comf...
# 16      Ljubljana to Frankfurt. Flight delayed for m...
# 17      Ljubljana to Vienna. Overall, the flight ser...
# 18     Two nice short flights from Ljubljana to Sara...
# Name: Review, dtype: object

# %%
Adria_rev_string = ', '.join(Adria_rev.astype(str))

# %%
def clean_text(text):
    words = word_tokenize(text.lower())
    cleaned_words = [word for word in words if word.isalpha() and word not in stop_words]
    return ' '.join(cleaned_words)

# %%
Adria_clean = clean_text(Adria_rev_string)

# %%
Adria_clean
# Out:
# 'book flight airline friend returned sofia amsterdam september days sent us sms informing flight cancelled straight days tried reach airline web agent get solution finally hours cancelled flight time minutes call waiting airline able get us flight lufthansa book adria airways unreliable case ruined last days holidays since needed phones bad experience rerouted cancelled flights last weekend adria airways original route ljubljana sarajevo return two weeks received email flight cancelled offered route change ljubljana sarajevo via munich flight back changed accepted first flight via munich two hours return flight got email flight cancelled rebook via hotline accept flight croatian zagreb reached ljubljana h later organize transport zagreb ljubljana cost book flights adria airways heard financial situation worst airline ever combined two flights save costs instead flying pristina ljubliana zürich fly pristina ljubliana münchen zürich arrive later ljubljana munich homebase airport adria airways ljubljana small relaxing convenient surrounded alps departure fantastic airplane modern crew nice ontime departure drinks without alcohol free paid white wine considering cheap ticket complain upgrades would available includes vienna sofia flight delayed hours cabin crew annoyed offer drinks passengers passing announced would give one drink per customer coffee nuisance made clear even though cart questions would normally go would drink anything would like drink bad customer traveling paris skopje may via ljubljana flight ljubljana skopje canceled days departure reason leaving us middle connection ljubljana even company booked hotel us made sure could take flight next day prevented us enjoying one day macedonia company agreed reimburse hostel night already paid two months claim still reply company company two times called multiple occasion company said would reimbursed months months later still received anything experience adria airways overall poor flight canceled reason flights took delayed terrible customer service unable give answer online claim reimbursing hostel night already paid ljubljana munich adria checkin system obviously barely coping possible obtain electronic boarding pass iphone wallet version adria site option failed without explanation able checkin return flight online neither adria lufthansa web site end made via lufthansa mobile app go figure issues reported customer care ignored experienced customer care policy couple years ago inquiry customer support basically ignored flight actually operated romanian company carpatair cabin outdated dirty funny smell lingering around latter stuck clothes day great meeting client cabin crew also quite disorganised mixed orders passengers sitting around would fly unfortunately company offering direct flight lju unpleasant experience family bought two return flights several days departure direct flights prague canceled flight warsaw merged prague flight added necessary stopover instead direct flight prague adria airways finally offered transfer via munich arrived airport found flight munich hour delay therefore possible catch next flight munich prague flight munich full people original canceled flight prague subsequently wanted continue prague although adria airways staff present airport one came inform passengers result tremendous confusion lack information ljubljana airport servicing staff finally informed us adria airways staff refused come also possible call adria airways hotline maybe overloaded due number disgruntled passengers next gate full people waiting delayed flight vienna also anybody adria airways could provide information unfortunately flight left without us forced ride munich airport km distant hotel next morning back permanent cancellation flights subsequent ignorance passengers surely way reduce operating costs cause outflow passengers airports around slovenia especially graz frankfurt ljubljana flight comfortable professional crew monitors passengers provide informatio ...

# %%
def clean_text_freq(text):
    words = word_tokenize(text.lower())
    cleaned_words = [word for word in words if word.isalpha() and word not in stop_words]
    freq_dist = FreqDist(cleaned_words)
    return freq_dist

# %%
Adria_dict = clean_text_freq(Adria_clean)

# %%
# options
x, y = np.ogrid[:300, :300]

mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)

# this actually generates the word cloud
wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(Adria_clean)

# and this displays it
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %%
# create an instance of the analyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#Creating functions 
def get_sentiment_scores(text):
    """
    Uses VADER within NLTK to calculate sentiment
    
    Args:
        text (str): a string containing the file or text
        
    Returns: 
        dict: a dictionary that VADER creates
    """
    
    score = analyzer.polarity_scores(text)
    return score

# %%
review = df["Review"]
reviewanalyser=review.apply(get_sentiment_scores)

# %%
reviewanalyser.values
# Out:
# array([{'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.9192},
#        {'neg': 0.114, 'neu': 0.878, 'pos': 0.008, 'compound': -0.9242},
#        {'neg': 0.031, 'neu': 0.849, 'pos': 0.121, 'compound': 0.7569},
#        ..., {'neg': 0.041, 'neu': 0.959, 'pos': 0.0, 'compound': -0.6917},
#        {'neg': 0.062, 'neu': 0.859, 'pos': 0.08, 'compound': 0.9588},
#        {'neg': 0.235, 'neu': 0.731, 'pos': 0.034, 'compound': -0.886}],
#       dtype=object)

# %%
reviewanalyser2=pd.DataFrame.from_dict(reviewanalyser)

# %%
reviewanalyser2.head()
# Out:
#                                               Review
# 0  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'comp...
# 1  {'neg': 0.114, 'neu': 0.878, 'pos': 0.008, 'co...
# 2  {'neg': 0.031, 'neu': 0.849, 'pos': 0.121, 'co...
# 4  {'neg': 0.079, 'neu': 0.846, 'pos': 0.074, 'co...
# 5  {'neg': 0.106, 'neu': 0.811, 'pos': 0.083, 'co...

# %%
Lufthansa_rev = Lufthansa_df['Review'].dropna()

# %%
Lufthansa_rev
# Out:
# 14078      London to Berlin via Munich. The day before ...
# 14079      Truly excellent experience with Lufthansa. F...
# 14080      Flight was delayed by about 60+ mins on the ...
# 14081     This is becoming a rule when I fly with Lufth...
# 14085      For reasons of bad weather we were redirecte...
#                                ...
# 14171      Customer service is rude because they know t...
# 14172      Legroom in Economy was below minimum. With t...
# 14173      Definitely not a big fan of Lufthansa but th...
# 14174      Business class seating is well below industr...
# 14175      FRA-MXP and LIN-FRA in December. Two unevent...
# Name: Review, Length: 71, dtype: object

# %%
Lufthansa_rev_string = ', '.join(Lufthansa_rev.astype(str))

# %%
Lufthansa_clean = clean_text(Lufthansa_rev_string)

# %%
Lufthansa_clean
# Out:
# 'london berlin via munich day scheduled flight london munich cancelled lufthansa shows app get refund straight away offered different flight call customer service given explanation flight cancelled customer service bad could hear despite fact asked several times speak original flight offered late flights options given via brussels zurich frankfurt one ca remember chose zurich one one earliest one almost operated swiss upon arriving heathrow everything seemed order one hour waiting flight got message flight delayed immediately went lufthansa desk check wo miss zurich berlin flight told worry late zurich deal problem hours later took heathrow landing advised swiss crew gates go connecting flights reaching gate saw screen boarding moments later announced flight cancelled passengers go transit desk arrived massive queue whilst waiting queue called lufthansa unable hear even though asked speak told help given already airport lufthansa opinion connecting flights called lufthansa received message app stating put flight day late night frankfurt would wait following morning flight berlin already short trip got frustrated lufthansa terrible customer service hung assisted swiss staff managed put berlin flight already closed override system get managed get berlin missed coach lost money help support customer service way back supposed fly berlin munich flight late reason given truly excellent experience lufthansa flight delayed hours due storms fra therefore transfer passengers would definitely miss connecting flights would land despite crew extremely friendly helpful dealt everybody concerns calmly professionally even served free drinks economy hats lufthansa ground crew also took care us well patience good humour flight delayed mins day due late arrival promised late opening counter filter ground staff departure despite assurances email update provided ground check staff well thankfully ground staff airport helpful could catch flight service staff helpful bit curt replies flight generally comfortable aircraft although price ticket passengers could probably small piece chocolate small bottled water arrival massive baggage delay many lufthansa arrivals affected customers baggage delayed hours service queue long despite situation service desk closed published time advising passengers follow queries qr code additional advice given hour waiting baggage airtag revealed baggage transported another belt far original belt choice would avoid flying lufthansa possible especially connecting flights testament perhaps queues service counters becoming rule fly lufthansa first staff rude even unfriendly second sit plane pilot makes announcement something wrong time tell us stuck without allowed take several hours also received water could serve us drinks last least arrived luggage got stuck somewhere way actually becoming rule flying lufthansa always unpleasant reasons bad weather redirected nuremberg sitting tarmac hour waiting water passed engine turned sweating like pigs complete silence second time problems paying reserve seat eco light ticket fact complimentary offerings small water single square chocolate terrible prices high behave like budget carrier due staffing shortages germany lufthansa also recently load luggage tell anyone end destination really poor service post last receive email saying flight lisbon lis fra hours delayed new departure time hours hours delay delay lost connecting flight india spent night frankfurt expense since trying contact lufthansa services upon myriad email exchanges yet obtain flight frankfurt connection diverted dusseldorf frankfurt airport closed due drone security pilot said refuelling everyone thought plane would return frankfurt instead without direction told exit plane idea going eventually ending baggage collection half hour later staff member showed said collect luggage would driven back frankfurt buses took hours everyone missed onward flights one met us huge bus loads passengers exited frankfurt one knew  ...

# %%
Lufthansa_dict = clean_text_freq(Lufthansa_clean)

# %%
x, y = np.ogrid[:300, :300]

mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)

# this actually generates the word cloud
wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(Lufthansa_clean)

# and this displays it
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %% [markdown]
# Sentiment Analysis

# %%
Turkish_rev = Turkish_df['Review'].dropna()

# %%
Turkish_rev
# Out:
# 21158     The ticketing and flight experiences, both, w...
# 21159      Last time that I will fly with Turkish Airli...
# 21161     Extra legroom not possible for over 65. We bo...
# 21162      My worst ever experience. I travelled with b...
# 21163     Flight from Beijing to Istanbul. Application ...
#                                ...
# 21251      Terrible experience. Started with a very poo...
# 21252      The customer service is terrible, they commu...
# 21254      It was the worst experience that I ever had....
# 21255      Because of covid and the fare I paid, my exp...
# 21256      Took TK from Manila to Ankara via Istanbul i...
# Name: Review, Length: 76, dtype: object

# %%
Turkish_rev_string = ', '.join(Turkish_rev.astype(str))

# %%
Turkish_clean = clean_text(Turkish_rev_string)

# %%
Turkish_clean
# Out:
# 'ticketing flight experiences unimpressive dismal exact booked flight family adults children atl del via ist back del atl via ist flights made sure complete seat selection online days flight paid desired amounts times turkish airlines disregarded paid selections decided change seats within hours flight departure meaning chance change online atl del spend extra time counter family sit together turkish decided assign us different seats different rows airplane food service well disappointing going atl del opted asian vegetarian meals hindu vegetarian meals given boiled spinach white rice boiled corn return flight del atl made food selection given bad experience flight surprise time options food beef meat vegetarian options apologies flight staff anything else staff handing food beef passengers without telling major red flag comes taking care nutritional food habits last time fly turkish airlines flight delayed miss connection rebook hours customer service efficient arrogant extra legroom possible booked flight tashkent heathrow via istanbul july tall wanted pay extra legroom seat economy booking website seat selection option flagged book exit row first time encountered flown many airlines exit row occupied older capable assisting evacuation accepted turkish airlines set maximum age searched seat plan airbus selected extra legroom seats bulkhead row shown exit row seemed ok completed booking paid weeks later completed possible hours less flight showed extra legroom seat allocation printing boarding passes discovered allocated seats row seat pitch small uncomfortable hour flight even painful passenger front reclines seems unclear unreliable booking process please warned require extra legroom book turkish airlines pay business class another comment might help travelers transiting istanbul make sure next flight leaves enough time transfer flight tashkent istanbul landed mins late took unbelievably long mins taxi long way around airport hardstanding another mins disembark aircraft took us mins walking fast pace transit bag scan next boarding gate passengers already started boarding flights could better toilets cleaned rubbish collected left floor landing maps would load information worst ever experience travelled business class arrived airport hours advance got stuck queue nearly hour turned elite members swamped priority lane tagged family members went super slow staff annoyed cabin crew hardly smiled food terrible deadly long layover first place departure made eligible free hotel program layover long offered nap room lounge came concierge desk told staff madam policy get nap room layover hours get hotel outside pay contract online customer service also terrible sent emails asking could layover period received unhelpful unfriendly answers flight beijing istanbul application working allowing proceed online check allow proceed seat selection upgrading purchase check airport person desk said transfer us emergency seats instead upgrade accepted received tickets boarding understand seats emergency seats asked transferred cabin crew asked us pay accept pay credit card accept kind credit card except chinese unbelievable anything negative say flight except breakfasts substandard even though nominal hour transit time ist ground staff departure gate told us minutes later closed boarding first late takeoff minutes second minutes landing taxi apron parking buses terminal followed long walk departure area f airport clearly designed maximise sales opportunities rather passenger convenience dally transfering ist message hour flight unless asleep cabin crew come offer water return layover succeeded tk provide hotel mercure airport old ataturk airport hours public transport new airport asked different hotel told system allocates spaces unchangeable hotel voucher booked wheelchair assistance disabled elderly trip ber tlv via ist first could online wheel chair arrived counter staff closing explained severely impaired could walk fast enough hall counter ...

# %%
Turkish_dict = clean_text_freq(Turkish_clean)

# %%
x, y = np.ogrid[:300, :300]

mask = (x - 150) ** 2 + (y - 150) ** 2 > 130 ** 2
mask = 255 * mask.astype(int)

# this actually generates the word cloud
wc = WordCloud(background_color="white", repeat=True, mask=mask)
wc.generate(Turkish_clean)

# and this displays it
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %% [markdown]
# Sentiment Analysis
